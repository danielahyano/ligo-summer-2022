# %%
from sifce import datatools, sims, network, tv
import pandas as pd
import numpy as np
from bilby.core.prior import Uniform, Sine, Cosine, PowerLaw, Constraint, DeltaFunction
from pycbc.detector import Detector
from bilby.core.prior import PriorDict
from pycbc.psd import analytical
from astropy.cosmology import Planck18
pd.set_option('display.max_columns', None)

# %%
net = network.Network(ifo_uptime_file="segment_list.segs",ifos=["H1", "L1", "V1"], psd_config_file="net_psds.psds", curves_are_asds=True)
net.load_psds()
net.psds_for_time(5)
# Out:
# {'H1': <pycbc.types.frequencyseries.FrequencySeries at 0x7f3ae9cca890>,
#  'L1': <pycbc.types.frequencyseries.FrequencySeries at 0x7f3ae9c723b0>,
#  'V1': <pycbc.types.frequencyseries.FrequencySeries at 0x7f3765d57fa0>}

# %%
prior_gw150914 = dict(mass_1= DeltaFunction(35),
                     mass_2= DeltaFunction(35),
                     a_1 = DeltaFunction(0.5),
                     a_2 = DeltaFunction(0.5),
                     tilt_1 = DeltaFunction(1.4),
                     tilt_2 = DeltaFunction(1.4),
                     phi_12 = DeltaFunction(3.09),
                     phi_jl = DeltaFunction(5.21),
                     theta_jn =  Sine(name='theta_jn'),
                     phase = DeltaFunction(1.04),
                     reference_frequency = DeltaFunction(20),
                     dec=Cosine(name='dec'),
                     ra=Uniform(name='ra', minimum=0, maximum=2 * np.pi, boundary='periodic'),
                     psi =  Uniform(name='psi', minimum=0, maximum=np.pi, boundary='periodic'),
                     geocent_time = DeltaFunction(5),
                     luminosity_distance = PowerLaw(alpha=2, name='luminosity_distance', minimum=50, maximum=6000, unit='Mpc', latex_label='$d_L$'))

# %%
prior_obj = PriorDict(dictionary = prior_gw150914)
pop = sims.SimulationSet(distribution=prior_obj, cosmology_model=Planck18, network=net)

# %%
pop.make_clean_simulations_dataframe()
pop.sample_distribution(100)
pop.fill_out_snr(N_sky=1000, N_scale=10)
# Out:
# 100it [03:04,  1.85s/it]
#        mass_1 mass_2   spin_1x   spin_1y   spin_1z   spin_2x   spin_2y  \
# 0        35.0   35.0  0.427966 -0.244178  0.084984 -0.414804  0.265924
# 1        35.0   35.0  0.427966 -0.244178  0.084984 -0.414804  0.265924
# 2        35.0   35.0  0.427966 -0.244178  0.084984 -0.414804  0.265924
# 3        35.0   35.0  0.427966 -0.244178  0.084984 -0.414804  0.265924
# 4        35.0   35.0  0.427966 -0.244178  0.084984 -0.414804  0.265924
# ...       ...    ...       ...       ...       ...       ...       ...
# 999995   35.0   35.0  0.427806 -0.244458  0.084984  -0.41463  0.266195
# 999996   35.0   35.0  0.427806 -0.244458  0.084984  -0.41463  0.266195
# 999997   35.0   35.0  0.427806 -0.244458  0.084984  -0.41463  0.266195
# 999998   35.0   35.0  0.427806 -0.244458  0.084984  -0.41463  0.266195
# 999999   35.0   35.0  0.427806 -0.244458  0.084984  -0.41463  0.266195
#
#          spin_2z  theta_jn phase        ra       dec       psi geocent_time  \
# 0       0.084984  0.988078  1.04  6.228149 -0.982061  2.463207          5.0
# 1       0.084984  0.988078  1.04  6.228149 -0.982061  2.463207          5.0
# 2       0.084984  0.988078  1.04  6.228149 -0.982061  2.463207          5.0
# 3       0.084984  0.988078  1.04  6.228149 -0.982061  2.463207          5.0
# 4       0.084984  0.988078  1.04  6.228149 -0.982061  2.463207          5.0
# ...          ...       ...   ...       ...       ...       ...          ...
# 999995  0.084984  0.845453  1.04  1.917393  0.006545  1.240885          5.0
# 999996  0.084984  0.845453  1.04  1.917393  0.006545  1.240885          5.0
# 999997  0.084984  0.845453  1.04  1.917393  0.006545  1.240885          5.0
# 999998  0.084984  0.845453  1.04  1.917393  0.006545  1.240885          5.0
# 999999  0.084984  0.845453  1.04  1.917393  0.006545  1.240885          5.0
#
#         luminosity_distance redshift chirp_mass total_mass mass_ratio  \
# 0               5435.118713      NaN        NaN        NaN        NaN
# 1               3551.211055      NaN        NaN        NaN        NaN
# 2               5531.825649      NaN        NaN        NaN        NaN
# 3               5328.165803      NaN        NaN        NaN        NaN
# 4               5818.589737      NaN        NaN        NaN        NaN
# ...                     ...      ...        ...        ...        ...
# 999995          5474.366857      NaN        NaN        NaN        NaN
# 999996          5924.332423      NaN        NaN        NaN        NaN
# 999997          5998.192691      NaN        NaN        NaN        NaN
# 999998          4758.709358      NaN        NaN        NaN        NaN
# 999999          4672.044942      NaN        NaN        NaN        NaN
#
#        symmetric_mass_ratio mass_1_source mass_2_source chirp_mass_source  \
# 0                       NaN           NaN           NaN               NaN
# 1                       NaN           NaN           NaN               NaN
# 2                       NaN           NaN           NaN               NaN
# 3                       NaN           NaN           NaN               NaN
# 4                       NaN           NaN           NaN               NaN
# ...                     ...           ...           ...               ...
# 999995                  NaN           NaN           NaN               NaN
# 999996                  NaN           NaN           NaN               NaN
# 999997                  NaN           NaN           NaN               NaN
# 999998                  NaN           NaN           NaN               NaN
# 999999                  NaN           NaN           NaN               NaN
#
#        total_mass_source  a_1  a_2 tilt_1 tilt_2 phi_12 phi_jl  \
# 0                    NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 1                    NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 2                    NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 3                    NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 4                    NaN  0.5  0.5    1.4    1.4   3.09   5.21
# ...                  ...  ...  ...    ...    ...    ...    ...
# 999995               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 999996               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 999997               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 999998               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 999999               NaN  0.5  0.5    1.4    1.4   3.09   5.21
#
#        reference_frequency intrinsic_index reference_snr_index cal_idx  \
# 0                     20.0             0.0                 NaN     NaN
# 1                     20.0             0.0                 NaN     NaN
# 2                     20.0             0.0                 NaN     NaN
# 3                     20.0             0.0                 NaN     NaN
# 4                     20.0             0.0                 NaN     NaN
# ...                    ...             ...                 ...     ...
# 999995                20.0            99.0                 NaN     NaN
# 999996                20.0            99.0                 NaN     NaN
# 999997                20.0            99.0                 NaN     NaN
# 999998                20.0            99.0                 NaN     NaN
# 999999                20.0            99.0                 NaN     NaN
#
#          opt_snr_H1    mf_snr_H1   opt_snr_L1    mf_snr_L1   opt_snr_V1  \
# 0       4299.790075  4299.790075  4815.392186  4815.392186  4882.044443
# 1       4299.790075  4299.790075  4815.392186  4815.392186  4882.044443
# 2       4299.790075  4299.790075  4815.392186  4815.392186  4882.044443
# 3       4299.790075  4299.790075  4815.392186  4815.392186  4882.044443
# 4       4299.790075  4299.790075  4815.392186  4815.392186  4882.044443
# ...             ...          ...          ...          ...          ...
# 999995  9223.406981  9223.406981  8730.916664  8730.916664  5560.666111
# 999996  9223.406981  9223.406981  8730.916664  8730.916664  5560.666111
# 999997  9223.406981  9223.406981  8730.916664  8730.916664  5560.666111
# 999998  9223.406981  9223.406981  8730.916664  8730.916664  5560.666111
# 999999  9223.406981  9223.406981  8730.916664  8730.916664  5560.666111
#
#           mf_snr_V1 opt_snr_net    mf_snr_net      iota     phi_1     phi_2
# 0       4882.044443    1.489178   8093.859064  0.993415  5.764697  2.571512
# 1       4882.044443    2.279183   8093.859064  0.993415  5.764697  2.571512
# 2       4882.044443    1.463144   8093.859064  0.993415  5.764697  2.571512
# 3       4882.044443     1.51907   8093.859064  0.993415  5.764697  2.571512
# 4       4882.044443    1.391034   8093.859064  0.993415  5.764697  2.571512
# ...             ...         ...           ...       ...       ...       ...
# 999995  5560.666111      2.5326  13864.384217  0.850791  5.764043  2.570858
# 999996  5560.666111    2.340244  13864.384217  0.850791  5.764043  2.570858
# 999997  5560.666111    2.311427  13864.384217  0.850791  5.764043  2.570858
# 999998  5560.666111    2.913476  13864.384217  0.850791  5.764043  2.570858
# 999999  5560.666111    2.967519  13864.384217  0.850791  5.764043  2.570858
#
# [1000000 rows x 45 columns]

# %%
def step(df):
    return (df['opt_snr_net'] > 11).astype(float)

# %%
Timevol = tv.TimeVolume(simulation=pop, function_detection=step)

# %%
Timevol.sensitive_volume_calc()
# Out:
# <Quantity 18.19716344 Gpc3 yr>
