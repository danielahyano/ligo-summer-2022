# %%
from sifce import datatools, sims, network, tv
import pandas as pd
import numpy as np
from bilby.core.prior import Uniform, Sine, Cosine, PowerLaw, Constraint, DeltaFunction
from pycbc.detector import Detector
from bilby.core.prior import PriorDict
from pycbc.psd import analytical
from astropy.cosmology import Planck18
pd.set_option('display.max_columns', None)

# %%
net = network.Network(ifo_uptime_file="segment_list.segs",ifos=["H1", "L1", "V1"], psd_config_file="net_psds.psds", curves_are_asds=True)
net.load_psds()
net.psds_for_time(5)
# Out:
# {'H1': <pycbc.types.frequencyseries.FrequencySeries at 0x7f5a375478e0>,
#  'L1': <pycbc.types.frequencyseries.FrequencySeries at 0x7f56b364eec0>,
#  'V1': <pycbc.types.frequencyseries.FrequencySeries at 0x7f56b364ead0>}

# %%
prior_gw150914 = dict(mass_1= DeltaFunction(35),
                     mass_2= DeltaFunction(35),
                     a_1 = DeltaFunction(0.5),
                     a_2 = DeltaFunction(0.5),
                     tilt_1 = DeltaFunction(1.4),
                     tilt_2 = DeltaFunction(1.4),
                     phi_12 = DeltaFunction(3.09),
                     phi_jl = DeltaFunction(5.21),
                     theta_jn =  Sine(name='theta_jn'),
                     phase = DeltaFunction(1.04),
                     reference_frequency = DeltaFunction(20),
                     dec=Cosine(name='dec'),
                     ra=Uniform(name='ra', minimum=0, maximum=2 * np.pi, boundary='periodic'),
                     psi =  Uniform(name='psi', minimum=0, maximum=np.pi, boundary='periodic'),
                     geocent_time = DeltaFunction(5),
                     luminosity_distance = PowerLaw(alpha=2, name='luminosity_distance', minimum=50, maximum=2000, unit='Mpc', latex_label='$d_L$'))

# %%
prior_obj = PriorDict(dictionary = prior_gw150914)
pop = sims.SimulationSet(distribution=prior_obj, cosmology_model=Planck18, network=net)
pop.sample_distribution(100)

# %%
pop.fill_out_snr(N_sky=10, N_scale=10)
# Out:
# WARNING: IERSWarning: failed to download https://datacenter.iers.org/data/9/finals2000A.all: <urlopen error _ssl.c:980: The handshake operation timed out> [astropy.utils.iers.iers]
# WARNING:astropy:IERSWarning: failed to download https://datacenter.iers.org/data/9/finals2000A.all: <urlopen error _ssl.c:980: The handshake operation timed out>
#      mass_1 mass_2   spin_1x   spin_1y   spin_1z   spin_2x   spin_2y  \
# 0      35.0   35.0   0.42783 -0.244416  0.084984 -0.414656  0.266154
# 1      35.0   35.0   0.42783 -0.244416  0.084984 -0.414656  0.266154
# 2      35.0   35.0   0.42783 -0.244416  0.084984 -0.414656  0.266154
# 3      35.0   35.0   0.42783 -0.244416  0.084984 -0.414656  0.266154
# 4      35.0   35.0   0.42783 -0.244416  0.084984 -0.414656  0.266154
# ...     ...    ...       ...       ...       ...       ...       ...
# 9995   35.0   35.0  0.428029 -0.244067  0.084984 -0.414873  0.265816
# 9996   35.0   35.0  0.428029 -0.244067  0.084984 -0.414873  0.265816
# 9997   35.0   35.0  0.428029 -0.244067  0.084984 -0.414873  0.265816
# 9998   35.0   35.0  0.428029 -0.244067  0.084984 -0.414873  0.265816
# 9999   35.0   35.0  0.428029 -0.244067  0.084984 -0.414873  0.265816
#
#        spin_2z  theta_jn phase        ra       dec       psi geocent_time  \
# 0     0.084984  0.864787  1.04  3.746022 -0.250626  2.693369          5.0
# 1     0.084984  0.864787  1.04  3.746022 -0.250626  2.693369          5.0
# 2     0.084984  0.864787  1.04  3.746022 -0.250626  2.693369          5.0
# 3     0.084984  0.864787  1.04  3.746022 -0.250626  2.693369          5.0
# 4     0.084984  0.864787  1.04  3.746022 -0.250626  2.693369          5.0
# ...        ...       ...   ...       ...       ...       ...          ...
# 9995  0.084984  1.053588  1.04  4.293186  0.559524   2.33712          5.0
# 9996  0.084984  1.053588  1.04  4.293186  0.559524   2.33712          5.0
# 9997  0.084984  1.053588  1.04  4.293186  0.559524   2.33712          5.0
# 9998  0.084984  1.053588  1.04  4.293186  0.559524   2.33712          5.0
# 9999  0.084984  1.053588  1.04  4.293186  0.559524   2.33712          5.0
#
#       luminosity_distance redshift chirp_mass total_mass mass_ratio  \
# 0             1553.105174      NaN        NaN        NaN        NaN
# 1             1968.531168      NaN        NaN        NaN        NaN
# 2             1543.562030      NaN        NaN        NaN        NaN
# 3             1674.478820      NaN        NaN        NaN        NaN
# 4             1894.269343      NaN        NaN        NaN        NaN
# ...                   ...      ...        ...        ...        ...
# 9995          1695.383719      NaN        NaN        NaN        NaN
# 9996          1807.220908      NaN        NaN        NaN        NaN
# 9997          1280.045653      NaN        NaN        NaN        NaN
# 9998          1911.969790      NaN        NaN        NaN        NaN
# 9999          1536.526410      NaN        NaN        NaN        NaN
#
#      symmetric_mass_ratio mass_1_source mass_2_source chirp_mass_source  \
# 0                     NaN           NaN           NaN               NaN
# 1                     NaN           NaN           NaN               NaN
# 2                     NaN           NaN           NaN               NaN
# 3                     NaN           NaN           NaN               NaN
# 4                     NaN           NaN           NaN               NaN
# ...                   ...           ...           ...               ...
# 9995                  NaN           NaN           NaN               NaN
# 9996                  NaN           NaN           NaN               NaN
# 9997                  NaN           NaN           NaN               NaN
# 9998                  NaN           NaN           NaN               NaN
# 9999                  NaN           NaN           NaN               NaN
#
#      total_mass_source  a_1  a_2 tilt_1 tilt_2 phi_12 phi_jl  \
# 0                  NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 1                  NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 2                  NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 3                  NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 4                  NaN  0.5  0.5    1.4    1.4   3.09   5.21
# ...                ...  ...  ...    ...    ...    ...    ...
# 9995               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 9996               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 9997               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 9998               NaN  0.5  0.5    1.4    1.4   3.09   5.21
# 9999               NaN  0.5  0.5    1.4    1.4   3.09   5.21
#
#      reference_frequency intrinsic_index reference_snr_index cal_idx  \
# 0                   20.0             0.0                 NaN     NaN
# 1                   20.0             0.0                 NaN     NaN
# 2                   20.0             0.0                 NaN     NaN
# 3                   20.0             0.0                 NaN     NaN
# 4                   20.0             0.0                 NaN     NaN
# ...                  ...             ...                 ...     ...
# 9995                20.0            99.0                 NaN     NaN
# 9996                20.0            99.0                 NaN     NaN
# 9997                20.0            99.0                 NaN     NaN
# 9998                20.0            99.0                 NaN     NaN
# 9999                20.0            99.0                 NaN     NaN
#
#        opt_snr_H1    mf_snr_H1   opt_snr_L1    mf_snr_L1   opt_snr_V1  \
# 0     9562.226304  9562.226304  17539.32016  17539.32016  3550.931317
# 1     9562.226304  9562.226304  17539.32016  17539.32016  3550.931317
# 2     9562.226304  9562.226304  17539.32016  17539.32016  3550.931317
# 3     9562.226304  9562.226304  17539.32016  17539.32016  3550.931317
# 4     9562.226304  9562.226304  17539.32016  17539.32016  3550.931317
# ...           ...          ...          ...          ...          ...
# 9995  5613.111568  5613.111568   6386.03186   6386.03186  2466.352609
# 9996  5613.111568  5613.111568   6386.03186   6386.03186  2466.352609
# 9997  5613.111568  5613.111568   6386.03186   6386.03186  2466.352609
# 9998  5613.111568  5613.111568   6386.03186   6386.03186  2466.352609
# 9999  5613.111568  5613.111568   6386.03186   6386.03186  2466.352609
#
#         mf_snr_V1 opt_snr_net    mf_snr_net      iota     phi_1     phi_2
# 0     3550.931317   13.063975  20289.727371  0.870126  5.764141  2.570956
# 1     3550.931317   10.307039  20289.727371  0.870126  5.764141  2.570956
# 2     3550.931317   13.144744  20289.727371  0.870126  5.764141  2.570956
# 3     3550.931317    12.11704  20289.727371  0.870126  5.764141  2.570956
# 4     3550.931317    10.71111  20289.727371  0.870126  5.764141  2.570956
# ...           ...         ...           ...       ...       ...       ...
# 9995  2466.352609    5.221684   8852.757739  1.058925  5.764957  2.571772
# 9996  2466.352609    4.898548   8852.757739  1.058925  5.764957  2.571772
# 9997  2466.352609     6.91597   8852.757739  1.058925  5.764957  2.571772
# 9998  2466.352609    4.630177   8852.757739  1.058925  5.764957  2.571772
# 9999  2466.352609     5.76154   8852.757739  1.058925  5.764957  2.571772
#
# [10000 rows x 45 columns]

# %%
def step(row):
    if row["opt_snr_net"] >= 11:
        return 1
    return 0

# %%
Timevol = tv.TimeVolume(simulation=pop, function_detection=step)

# %%
Timevol.sensitive_volume_calc()
# Out:
# <Quantity 1.48665468 Gpc3 yr>
